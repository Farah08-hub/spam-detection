# %%
import pandas as pd

df = pd.read_csv("../data/spam.csv", encoding="utf-8-sig", on_bad_lines='skip')
df = df.iloc[:, :2]
df.columns = ['label', 'message']

df['label'] = df['label'].str.split(',').str[0]
df = df[df['label'].isin(['ham', 'spam'])]
df['label'].value_counts()
# Out:
# label
# ham     4807
# spam     745
# Name: count, dtype: int64

# %%
from src.preprocessing.clean_text import clean_text
clean_text("FREE entry!!! Win $$$ now")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.preprocessing.clean_text import clean_text
#       2 clean_text("FREE entry!!! Win $$$ now")
#
# ModuleNotFoundError: No module named 'src'
